# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
df = pd.read_csv('/home/prakritisaldiya/prakriti/Prakriti_LaunchPad/Week_6/Day_2/src/data/processed/final.csv')

df.head()
# Out:
#    Sex  Pclass       Age  IsChild  IsElderly      Fare  HighFareFlag  \
# 0    1       3 -0.510807        0          0 -0.820096             0
# 1    0       1  0.673472        0          0  3.315557             1
# 2    0       3 -0.214737        0          0 -0.776500             0
# 3    0       1  0.451420        0          0  2.141171             1
# 4    1       3  0.451420        0          0 -0.768427             0
#
#    FareAgeRatio  Embarked_C  Embarked_S  Embarked_Q  Survived
# 0     -0.375728           0           1           0         0
# 1      0.293376           1           0           0         1
# 2     -0.385326           0           1           0         1
# 3      0.137320           0           1           0         1
# 4     -0.416251           0           1           0         0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sex           683 non-null    int64
#  1   Pclass        683 non-null    int64
#  2   Age           683 non-null    float64
#  3   IsChild       683 non-null    int64
#  4   IsElderly     683 non-null    int64
#  5   Fare          683 non-null    float64
#  6   HighFareFlag  683 non-null    int64
#  7   FareAgeRatio  683 non-null    float64
#  8   Embarked_C    683 non-null    int64
#  9   Embarked_S    683 non-null    int64
#  10  Embarked_Q    683 non-null    int64
#  11  Survived      683 non-null    int64
# dtypes: float64(3), int64(9)
# memory usage: 64.2 KB

# %%
df.describe()
# Out:
#               Sex      Pclass           Age     IsChild   IsElderly  \
# count  683.000000  683.000000  6.830000e+02  683.000000  683.000000
# mean     0.663250    2.423133  1.040326e-16    0.092240    0.026354
# std      0.472945    0.762688  1.000733e+00    0.289577    0.160304
# min      0.000000    1.000000 -2.108103e+00    0.000000    0.000000
# 25%      0.000000    2.000000 -5.848243e-01    0.000000    0.000000
# 50%      1.000000    3.000000 -6.670237e-02    0.000000    0.000000
# 75%      1.000000    3.000000  4.514195e-01    0.000000    0.000000
# max      1.000000    3.000000  3.782203e+00    1.000000    1.000000
#
#                Fare  HighFareFlag  FareAgeRatio  Embarked_C  Embarked_S  \
# count  6.830000e+02    683.000000  6.830000e+02  683.000000  683.000000
# mean   6.762120e-17      0.496340  8.322609e-17    0.155198    0.762811
# std    1.000733e+00      0.500353  1.000733e+00    0.362358    0.425671
# min   -1.288344e+00      0.000000 -5.151688e-01    0.000000    0.000000
# 25%   -7.765005e-01      0.000000 -3.829580e-01    0.000000    1.000000
# 50%   -4.164337e-01      0.000000 -2.974786e-01    0.000000    1.000000
# 75%    4.264132e-01      1.000000 -9.662320e-02    0.000000    1.000000
# max    3.458725e+00      1.000000  9.858289e+00    1.000000    1.000000
#
#        Embarked_Q    Survived
# count  683.000000  683.000000
# mean     0.081991    0.363104
# std      0.274552    0.481247
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      0.000000    1.000000
# max      1.000000    1.000000

# %%
numeric_df = df.select_dtypes(include="number")

plt.figure(figsize=(12, 8))
sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)
plt.title("Correlation Matrix")
plt.show()

# %%
# Target Distribution
plt.figure()
ax = sns.countplot(x="Survived", data=df)
plt.title("Target Distribution (Survived)")

# Add percentages on bars
total = len(df)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2., height,
            '{:1.1f}%'.format(100*height/total),
            ha="center")

plt.show()

# %%
df.hist(figsize=(14, 10))
plt.suptitle("Feature Distributions", fontsize=16)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()
