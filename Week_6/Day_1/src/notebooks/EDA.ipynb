# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
df = pd.read_csv('/home/prakritisaldiya/prakriti/Prakriti_LaunchPad/Week_6/Day2/src/data/processed/final.csv')

df.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare Embarked
# 0         0       3    male  22.0   7.2500        S
# 1         1       1  female  38.0  71.2833        C
# 2         1       3  female  26.0   7.9250        S
# 3         1       1  female  35.0  53.1000        S
# 4         0       3    male  35.0   8.0500        S

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  683 non-null    int64
#  1   Pclass    683 non-null    int64
#  2   Sex       683 non-null    str
#  3   Age       683 non-null    float64
#  4   Fare      683 non-null    float64
#  5   Embarked  683 non-null    str
# dtypes: float64(2), int64(2), str(2)
# memory usage: 32.1 KB

# %%
df.describe()
# Out:
#          Survived      Pclass         Age        Fare
# count  683.000000  683.000000  683.000000  683.000000
# mean     0.363104    2.423133   28.901171   19.947743
# std      0.481247    0.762688   13.520235   15.494586
# min      0.000000    1.000000    0.420000    0.000000
# 25%      0.000000    2.000000   21.000000    7.925000
# 50%      0.000000    3.000000   28.000000   13.500000
# 75%      1.000000    3.000000   35.000000   26.550000
# max      1.000000    3.000000   80.000000   73.500000

# %%
numeric_df = df.select_dtypes(include="number")

plt.figure(figsize=(12, 8))
sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)
plt.title("Correlation Matrix")
plt.show()

# %%
# Target Distribution
plt.figure()
ax = sns.countplot(x="Survived", data=df)
plt.title("Target Distribution (Survived)")

# Add percentages on bars
total = len(df)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2., height,
            '{:1.1f}%'.format(100*height/total),
            ha="center")

plt.show()

# %%
df.hist(figsize=(14, 10))
plt.suptitle("Feature Distributions", fontsize=16)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()
